# %%
# %load_ext autoreload

# %%
# %autoreload
from data_samples import test_on_samples

from tempo_estimators_robert import PhaseNoveltyEstimator

# %%
test_on_samples(PhaseNoveltyEstimator, split="test", measure_time=True)
# Out:
# Running analysis on amen-break-varying-speed
# Model ran for 3340.7735 ms
# Running analysis on bad-fills
# Model ran for 2611.9054 ms
# Running analysis on bad-purdie-in-6-4
# Model ran for 1517.013 ms
# Running analysis on not-just-8ths
# Model ran for 3981.5332 ms
# Running analysis on varying-a-bit
# Model ran for 2408.5033 ms
