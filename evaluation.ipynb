# %%
# %load_ext autoreload

# %%
# %autoreload

from src.data_samples import test_on_samples
from src.tempo_estimators import PhaseNoveltyEstimator

# %%
test_on_samples(PhaseNoveltyEstimator, split="test", measure_time=True)
# Out:
# Running analysis on bad-fills
# Model ran for 2664.1293 ms
# Running analysis on bad-purdie-in-6-4
# Model ran for 1637.046 ms
# Running analysis on not-just-8ths
# Model ran for 3636.1357 ms
# Running analysis on varying-a-bit
# Model ran for 2172.1142 ms
